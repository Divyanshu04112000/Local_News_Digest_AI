# %%
# !pip install python-dotenv

# %%
# !pip install crewai

# %%
# !pip install python-dotenv crewai crewai-tools
# !pip install requests beautifulsoup4

# %%
import os
from crewai import Agent, Task, Crew
from crewai_tools import ScrapeWebsiteTool

# 1️⃣ Set your API key here (replace with your real key)
os.environ["OPENAI_API_KEY"] = "sk-proj-xyz"

def main():
    """
    Main function to run the local news digest crew.
    """
    print("## Welcome to the Local News Digest Crew! ##")
    print('-----------------------------------------------')

    # You can change this to any local news website
    news_website_url = 'https://www.tribuneindia.com/news/state/uttar-pradesh'

    # 1. Define the Tool
    scrape_tool = ScrapeWebsiteTool()

    # 2. Define the Agents
    scraper = Agent(
        role='Local News Scraper',
        goal=f'Scrape the full content of the top news articles from {news_website_url}',
        backstory="""You are an expert web scraper...""",
        verbose=True,
        allow_delegation=False,
        tools=[scrape_tool]
    )

    summarizer = Agent(
        role='Expert News Summarizer',
        goal='Create a concise, easy-to-read summary of each news article',
        backstory="""You are a seasoned journalist...""",
        verbose=True,
        allow_delegation=False,
    )

    classifier = Agent(
        role='News Category Classifier',
        goal='Classify each summarized news article into a relevant category',
        backstory="""You are a meticulous librarian...""",
        verbose=True,
        allow_delegation=False,
    )

    # 3. Define Tasks
    scrape_task = Task(
        description=f'Scrape the news articles from the website: {news_website_url}',
        expected_output='A clean list of the full text content of the latest news articles.',
        agent=scraper
    )

    summarize_task = Task(
        description="For each article, create a compelling and concise summary no more than 3 sentences.",
        expected_output='A list of summarized news articles, each with a clear headline.',
        agent=summarizer,
        context=[scrape_task]
    )

    classify_task = Task(
        description="""Take the list of summarized articles and classify each into:
        - Local Politics
        - Business
        - Sports
        - Technology
        - Environment
        - General News""",
        expected_output="A final report with each news summary neatly organized.",
        agent=classifier,
        context=[summarize_task]
    )

    # 4. Assemble and Run
    news_digest_crew = Crew(
        agents=[scraper, summarizer, classifier],
        tasks=[scrape_task, summarize_task, classify_task],
        verbose=True
    )

    print("\n🚀 Crew: Kicking off the Local News Digest creation...\n")
    result = news_digest_crew.kickoff()

    print("\n\n########################")
    print("✅ Crew: Here is your Local News Digest!")
    print("########################\n")
    print(result)

if __name__ == '__main__':
    main()
# Out:
# ## Welcome to the Local News Digest Crew! ##
# -----------------------------------------------
#
# 🚀 Crew: Kicking off the Local News Digest creation...
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 9f74b052-afd9-493c-96d8-ef9b39de517b                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# ...
